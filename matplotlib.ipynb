# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %%
plt.plot([1,2,3,4],[1,4,9,16],'r')

# %%
#creating a dataframe
df = pd.DataFrame([[1,2],[1,4]],columns=['a','b'],index=['one','two'])
df.head()
# Out:
#      a  b
# one  1  2
# two  1  4

# %%
#plotting the dataframe
df.plot(kind='bar')
plt.show()
